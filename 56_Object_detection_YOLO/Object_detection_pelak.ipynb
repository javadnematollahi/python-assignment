# %%
# !pip -q install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\programming\Pylearn\56_YOLO\Object_detection_pelak.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/programming/Pylearn/56_YOLO/Object_detection_pelak.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 315MB/s]

# %%
results = model.train(data="/content/drive/MyDrive/dataset/398_data_pelak.yaml")
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
best_model = YOLO("/content/runs/detect/train4/weights/best.pt")

result = best_model("/content/drive/MyDrive/dataset/398_pelak_images/test/images/photo_2023-11-07_14-34-47_jpg.rf.bcd55d35872394242ddd40645d7294cb.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/dataset/398_pelak_images/test/images/photo_2023-11-07_14-34-47_jpg.rf.bcd55d35872394242ddd40645d7294cb.jpg: 640x640 3 License-Plates, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
